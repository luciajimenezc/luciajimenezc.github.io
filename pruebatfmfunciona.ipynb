# %% [markdown]
# <a href="https://colab.research.google.com/github/luciajimenezc/luciajimenezc.github.io/blob/main/pruebatfmfunciona.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install jsondiff
import requests
import json
import jsondiff
from datetime import datetime, timedelta


def date_parser(date: datetime) -> str:
    """Converts a datetime object to a string in the format YYYYMMDD."""
    return date.strftime("%Y%m%d")


def get_data(date=date_parser(datetime.now())):
    """
    Retrieves data from the API for a specific date.
    Returns a dictionary of the API response or an error message.
    """
    print(f"Getting data for {date} ...")

    headers = {
        "Accept": "application/json",
        "Referer": "https://www.boe.es/datosabiertos/api/api.php",
    }
    response = requests.get(
        f"https://www.boe.es/datosabiertos/api/boe/sumario/{date}", headers=headers
    )

    if response.status_code == 200:
        try:
            data = response.json()
        except ValueError:
            data = {"Error": "Invalid JSON in response"}
    elif response.status_code == 404:
        data = {"No data": f"No data available for {date}"}
    else:
        data = {"Error": f"Error retrieving data for {date}: {response.status_code}"}

    return data


def sanitize_keys(data):
    """
    Recursively converts all keys in a dictionary to strings.
    Handles dictionaries, lists, and other types safely.
    """
    if isinstance(data, dict):
        return {str(k): sanitize_keys(v) for k, v in data.items()}
    elif isinstance(data, list):
        return [sanitize_keys(item) for item in data]
    # For other data types (str, int, None, etc.), return as-is
    return data


def normalize_diff(diff, original, updated):
    """
    Normalizes a jsondiff.diff output to a consistent structure.
    Maps diff operations like $replace, $delete, $add to a unified format.
    """
    if not isinstance(diff, dict):
        # Ensure diff is a dictionary; if not, return an empty structure.
        return {}

    normalized = {}

    for key, value in diff.items():
        # Ensure the key is a string
        str_key = str(key)

        if isinstance(value, dict) and "$replace" in value:
            # Handle $replace operation
            normalized[str_key] = {
                "action": "replace",
                "before": original.get(key),
                "after": updated.get(key),
            }
        elif str_key.startswith("$delete"):
            # Handle $delete operation
            normalized[str_key] = {
                "action": "delete",
                "before": original.get(key),
                "after": None,
            }
        elif str_key.startswith("$add"):
            # Handle $add operation
            normalized[str_key] = {
                "action": "add",
                "before": None,
                "after": updated.get(key),
            }
        elif isinstance(value, dict):
            # Recursive handling for nested diffs
            normalized[str_key] = normalize_diff(
                value, original.get(key, {}), updated.get(key, {})
            )
        else:
            # For other cases (e.g., scalar values in the diff), record them directly.
            normalized[str_key] = {
                "action": "modify",
                "before": original.get(key),
                "after": value,
            }
    return normalized


def write_data(data, fname):
    """
    Writes data to a JSON file, ensuring all keys are sanitized for JSON serialization.
    """
    print(f"Writing data to {fname} ...")
    sanitized_data = sanitize_keys(data)

    with open(fname, "w") as f:
        try:
            json.dump(sanitized_data, f, indent=4)
            print(f"Data successfully written to {fname}")
        except TypeError as e:
            print(f"Error writing JSON: {e}")
            raise


def get_year_comparison(year):
    """
    Retrieves data for each day of a year, calculates daily differences, and saves the result.
    Ensures a consistent structure for all outputs.
    """
    yearly_report = {}

    for i in range(1, 5):  # Adjust range as needed for testing or full-year data.
        current = datetime.strptime(f"{year} {i}", "%Y %j")
        date = date_parser(current)
        data = get_data(date)

        # Compare data with the previous day and store differences.
        if i > 1:
            yesterday = current - timedelta(days=1)
            yesterday_date = date_parser(yesterday)

            # Sanitize keys before comparing
            sanitized_yesterday = sanitize_keys(yearly_report[yesterday_date])
            sanitized_data = sanitize_keys(data)

            diff = jsondiff.diff(sanitized_yesterday, sanitized_data)
            normalized_diff = normalize_diff(diff, sanitized_yesterday, sanitized_data)

            if normalized_diff:
                yearly_report[date] = {"date": date, "changes": normalized_diff}
        else:
            yearly_report[date] = {"date": date, "changes": {"$replace": data}}

    # Save yearly report to file.
    write_data(yearly_report, f"yearly_report_{year}.json")


# Execute the script for the year 2021.
if __name__ == "__main__":
    try:
        get_year_comparison(2024)
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# Requirement already satisfied: jsondiff in /usr/local/lib/python3.10/dist-packages (2.2.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from jsondiff) (6.0.2)
# Getting data for 20240101 ...
# Getting data for 20240102 ...
# Getting data for 20240103 ...
# Getting data for 20240104 ...
# Writing data to yearly_report_2024.json ...
# Data successfully written to yearly_report_2024.json

# %% [markdown]
# comparar datos

# %%
# !ls
import json

# Abre y carga el archivo JSON
with open('yearly_report_2024.json', 'r') as file:
    data = json.load(file)

# Mostrar el contenido del archivo en formato legible
print(json.dumps(data, indent=4))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#                                                                     "identificador": "BOE-A-2024-138",
#                                                                     "control": "2024/2",
#                                                                     "titulo": "Real Decreto 1167/2023, de 19 de diciembre, por el que se nombra Decano de los Juzgados de Arenys de Mar al Magistrado don Jorge Langarita Cerrada.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "191632",
#                                                                         "szKBytes": "187",
#                                                                         "pagina_inicial": "558",
#                                                                         "pagina_final": "558",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-138.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-138",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-138"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-139",
#                                                                     "control": "2024/3",
#                                                                     "titulo": "Real Decreto 1168/2023, de 19 de diciembre, por el que se nombra Decano de los Juzgados de Vitoria-Gasteiz al Magistrado don Ignacio S\u00e1nchez Mor\u00e1n.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "191392",
#                                                                         "szKBytes": "187",
#                                                                         "pagina_inicial": "559",
#                                                                         "pagina_final": "559",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-139.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-139",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-139"
#                                                                 }
#                                                             ]
#                                                         },
#                                                         {
#                                                             "nombre": "Situaciones",
#                                                             "item": {
#                                                                 "identificador": "BOE-A-2024-140",
#                                                                 "control": "2023/24929",
#                                                                 "titulo": "Acuerdo de 6 de septiembre de 2023, de la Comisi\u00f3n Permanente del Consejo General del Poder Judicial, por el que se declara la jubilaci\u00f3n voluntaria anticipada de la Magistrada do\u00f1a Mar\u00eda Josefa Santamar\u00eda Santigosa.",
#                                                                 "url_pdf": {
#                                                                     "szBytes": "191385",
#                                                                     "szKBytes": "187",
#                                                                     "pagina_inicial": "560",
#                                                                     "pagina_final": "560",
#                                                                     "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-140.pdf"
#                                                                 },
#                                                                 "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-140",
#                                                                 "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-140"
#                                                             }
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "9279",
#                                                     "nombre": "MINISTERIO DE HACIENDA Y FUNCI\u00d3N P\u00daBLICA",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Nombramientos",
#                                                             "item": [
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-141",
#                                                                     "control": "2023/27011",
#                                                                     "titulo": "Resoluci\u00f3n de 27 de diciembre de 2023, de la Secretar\u00eda de Estado de Funci\u00f3n P\u00fablica, por la que se nombra personal funcionario de carrera, por el sistema de promoci\u00f3n interna, del Cuerpo de Ingenieros T\u00e9cnicos de Arsenales de la Armada.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "225327",
#                                                                         "szKBytes": "220",
#                                                                         "pagina_inicial": "561",
#                                                                         "pagina_final": "563",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-141.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-141",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-141"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-142",
#                                                                     "control": "2023/27012",
#                                                                     "titulo": "Resoluci\u00f3n de 27 de diciembre de 2023, de la Secretar\u00eda de Estado de Funci\u00f3n P\u00fablica, por la que se nombra personal funcionario de carrera, por el sistema general de acceso libre, de la Escala de Titulados Superiores de Organismos Aut\u00f3nomos del Ministerio de Industria, Comercio y Turismo, especialidades de Propiedad Industrial y de Metrolog\u00eda.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "320944",
#                                                                         "szKBytes": "313",
#                                                                         "pagina_inicial": "564",
#                                                                         "pagina_final": "569",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-142.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-142",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-142"
#                                                                 }
#                                                             ]
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "9591",
#                                                     "nombre": "MINISTERIO DE INDUSTRIA Y TURISMO",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Destinos",
#                                                             "item": {
#                                                                 "identificador": "BOE-A-2024-143",
#                                                                 "control": "2023/27013",
#                                                                 "titulo": "Resoluci\u00f3n de 27 de diciembre de 2023, de la Subsecretar\u00eda, por la que se corrigen errores en la de 29 de noviembre de 2023, por la que se resuelve la convocatoria de libre designaci\u00f3n, efectuada por Resoluci\u00f3n de 18 de septiembre de 2023, en las Oficinas Econ\u00f3micas y Comerciales en el exterior.",
#                                                                 "url_pdf": {
#                                                                     "szBytes": "221370",
#                                                                     "szKBytes": "216",
#                                                                     "pagina_inicial": "570",
#                                                                     "pagina_final": "572",
#                                                                     "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-143.pdf"
#                                                                 },
#                                                                 "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-143",
#                                                                 "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-143"
#                                                             }
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "4110",
#                                                     "nombre": "MINISTERIO DE CULTURA",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Personal laboral",
#                                                             "item": {
#                                                                 "identificador": "BOE-A-2024-144",
#                                                                 "control": "2023/27014",
#                                                                 "titulo": "Resoluci\u00f3n de 27 de diciembre de 2023, de la Subsecretar\u00eda, por la que se adjudica plaza a los aspirantes que han superado el proceso selectivo para el ingreso, por concurso, como personal laboral fijo, en los grupos profesionales 4G, M1 y E2, sujetos al IV Convenio colectivo \u00fanico para el personal laboral de la Administraci\u00f3n General del Estado en el Instituto de la Cinematograf\u00eda y de las Artes Audiovisuales, convocado por Resoluci\u00f3n de 27 de diciembre de 2022.",
#                                                                 "url_pdf": {
#                                                                     "szBytes": "213473",
#                                                                     "szKBytes": "208",
#                                                                     "pagina_inicial": "573",
#                                                                     "pagina_final": "574",
#                                                                     "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-144.pdf"
#                                                                 },
#                                                                 "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-144",
#                                                                 "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-144"
#                                                             }
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "310",
#                                                     "nombre": "UNIVERSIDADES",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Nombramientos",
#                                                             "item": [
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-145",
#                                                                     "control": "2023/26721",
#                                                                     "titulo": "Resoluci\u00f3n de 18 de diciembre de 2023, de la Universidad de A Coru\u00f1a, por la que se nombra Profesora Titular de Universidad a do\u00f1a Mar\u00eda del Mar Castellanos Rodrigo.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "192128",
#                                                                         "szKBytes": "188",
#                                                                         "pagina_inicial": "575",
#                                                                         "pagina_final": "575",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-145.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-145",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-145"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-146",
#                                                                     "control": "2023/26723",
#                                                                     "titulo": "Resoluci\u00f3n de 22 de diciembre de 2023, de la Universidad de La Laguna, por la que se nombra Profesor Titular de Universidad a don S\u00e9bastien Comer\u00f3n Limbourg.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "191783",
#                                                                         "szKBytes": "187",
#                                                                         "pagina_inicial": "576",
#                                                                         "pagina_final": "576",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-146.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-146",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-146"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-147",
#                                                                     "control": "2023/26724",
#                                                                     "titulo": "Resoluci\u00f3n de 22 de diciembre de 2023, de la Universidad de Le\u00f3n, por la que se nombra Profesora Titular de Universidad a do\u00f1a Laura Rodr\u00edguez Garc\u00eda.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "191720",
#                                                                         "szKBytes": "187",
#                                                                         "pagina_inicial": "577",
#                                                                         "pagina_final": "577",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-147.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-147",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-147"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-148",
#                                                                     "control": "2023/26725",
#                                                                     "titulo": "Resoluci\u00f3n de 22 de diciembre de 2023, de la Universidad de Murcia, por la que se nombra Profesora Titular de Universidad a do\u00f1a Mar\u00eda Pemart\u00edn Gonz\u00e1lez-Adalid.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "191374",
#                                                                         "szKBytes": "187",
#                                                                         "pagina_inicial": "578",
#                                                                         "pagina_final": "578",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-148.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-148",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-148"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-149",
#                                                                     "control": "2023/26726",
#                                                                     "titulo": "Resoluci\u00f3n de 22 de diciembre de 2023, de la Universidad de Santiago de Compostela, por la que se nombra Profesora Titular de Universidad a do\u00f1a Natalia Seoane Iglesias.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "200334",
#                                                                         "szKBytes": "196",
#                                                                         "pagina_inicial": "579",
#                                                                         "pagina_final": "580",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-149.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-149",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-149"
#                                                                 }
#                                                             ]
#                                                         }
#                                                     ]
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "codigo": "2B",
#                                             "nombre": "II. Autoridades y personal. - B. Oposiciones y concursos",
#                                             "departamento": [
#                                                 {
#                                                     "codigo": "9562",
#                                                     "nombre": "MINISTERIO DE ASUNTOS EXTERIORES, UNI\u00d3N EUROPEA Y COOPERACI\u00d3N",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Personal laboral",
#                                                             "item": {
#                                                                 "identificador": "BOE-A-2024-150",
#                                                                 "control": "2024/12",
#                                                                 "titulo": "Resoluci\u00f3n de 28 de diciembre de 2023, del Consorcio Casa \u00c1frica, por la que se aprueba la oferta p\u00fablica de empleo 2023.",
#                                                                 "url_pdf": {
#                                                                     "szBytes": "192577",
#                                                                     "szKBytes": "188",
#                                                                     "pagina_inicial": "581",
#                                                                     "pagina_final": "581",
#                                                                     "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-150.pdf"
#                                                                 },
#                                                                 "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-150",
#                                                                 "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-150"
#                                                             }
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "6110",
#                                                     "nombre": "MINISTERIO DE DEFENSA",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Escala de Cient\u00edficos Superiores de la Defensa",
#                                                             "item": {
#                                                                 "identificador": "BOE-A-2024-151",
#                                                                 "control": "2024/13",
#                                                                 "titulo": "Resoluci\u00f3n 400/38510/2023, de 14 de diciembre, de la Subsecretar\u00eda, por la que se convoca proceso selectivo para ingreso, por el sistema general de acceso libre, a la Escala de Cient\u00edficos Superiores de la Defensa.",
#                                                                 "url_pdf": {
#                                                                     "szBytes": "487145",
#                                                                     "szKBytes": "476",
#                                                                     "pagina_inicial": "582",
#                                                                     "pagina_final": "615",
#                                                                     "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-151.pdf"
#                                                                 },
#                                                                 "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-151",
#                                                                 "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-151"
#                                                             }
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "4110",
#                                                     "nombre": "MINISTERIO DE CULTURA",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Personal laboral",
#                                                             "item": {
#                                                                 "identificador": "BOE-A-2024-152",
#                                                                 "control": "2023/27022",
#                                                                 "titulo": "Resoluci\u00f3n de 28 de diciembre de 2023, de la Subsecretar\u00eda, por la que se modifica la composici\u00f3n del Tribunal calificador del proceso selectivo para ingreso por concurso como personal laboral fijo, en los grupos profesionales 1G, 3G, 4G, M1, E2 y E1, sujetos al IV Convenio colectivo \u00fanico para el personal laboral de la Administraci\u00f3n General del Estado, convocado por Resoluci\u00f3n de 22 de diciembre de 2022.",
#                                                                 "url_pdf": {
#                                                                     "szBytes": "192765",
#                                                                     "szKBytes": "188",
#                                                                     "pagina_inicial": "616",
#                                                                     "pagina_final": "616",
#                                                                     "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-152.pdf"
#                                                                 },
#                                                                 "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-152",
#                                                                 "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-152"
#                                                             }
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "9589",
#                                                     "nombre": "MINISTERIO DE ECONOM\u00cdA, COMERCIO Y EMPRESA",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Personal laboral",
#                                                             "item": {
#                                                                 "identificador": "BOE-A-2024-153",
#                                                                 "control": "2023/26921",
#                                                                 "titulo": "Resoluci\u00f3n de 26 de diciembre de 2023, de la Subsecretar\u00eda, por la que se aprueba relaci\u00f3n de aspirantes que han superado el proceso selectivo, por el sistema general de acceso libre, por concurso, en el marco de estabilizaci\u00f3n de empleo temporal, para la provisi\u00f3n de plazas de personal laboral, grupo profesional E1, especialidad Servicios Administrativos, convocado por Resoluci\u00f3n de 27 de diciembre de 2022.",
#                                                                 "url_pdf": {
#                                                                     "szBytes": "276429",
#                                                                     "szKBytes": "270",
#                                                                     "pagina_inicial": "617",
#                                                                     "pagina_final": "621",
#                                                                     "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-153.pdf"
#                                                                 },
#                                                                 "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-153",
#                                                                 "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-153"
#                                                             }
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "9579",
#                                                     "nombre": "MINISTERIO DE INCLUSI\u00d3N, SEGURIDAD SOCIAL Y MIGRACIONES",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Cuerpo Superior de Letrados de la Administraci\u00f3n de la Seguridad Social",
#                                                             "item": {
#                                                                 "identificador": "BOE-A-2024-154",
#                                                                 "control": "2023/27023",
#                                                                 "titulo": "Resoluci\u00f3n de 26 de diciembre de 2023, de la Subsecretar\u00eda, por la que se publica la relaci\u00f3n definitiva de aspirantes que han aprobado en la fase de oposici\u00f3n del proceso selectivo para ingreso, por el sistema general de acceso libre, en el Cuerpo Superior de Letrados de la Administraci\u00f3n de la Seguridad Social, convocado por Resoluci\u00f3n de 17 de enero de 2023.",
#                                                                 "url_pdf": {
#                                                                     "szBytes": "227255",
#                                                                     "szKBytes": "222",
#                                                                     "pagina_inicial": "622",
#                                                                     "pagina_final": "624",
#                                                                     "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-154.pdf"
#                                                                 },
#                                                                 "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-154",
#                                                                 "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-154"
#                                                             }
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "9525",
#                                                     "nombre": "ADMINISTRACI\u00d3N LOCAL",
#                                                     "epigrafe": [
#                                                         {
#                                                             "nombre": "Personal funcionario y laboral",
#                                                             "item": [
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-155",
#                                                                     "control": "2023/26924",
#                                                                     "titulo": "Resoluci\u00f3n de 4 de diciembre de 2023, del Ayuntamiento de Museros (Valencia), referente a la convocatoria para proveer varias plazas.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "190624",
#                                                                         "szKBytes": "186",
#                                                                         "pagina_inicial": "625",
#                                                                         "pagina_final": "625",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-155.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-155",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-155"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-156",
#                                                                     "control": "2023/26927",
#                                                                     "titulo": "Resoluci\u00f3n de 14 de diciembre de 2023, del Ayuntamiento de Ferrol (A Coru\u00f1a), referente a la convocatoria para proveer varias plazas.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "190949",
#                                                                         "szKBytes": "186",
#                                                                         "pagina_inicial": "626",
#                                                                         "pagina_final": "626",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-156.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-156",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-156"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-157",
#                                                                     "control": "2023/26626",
#                                                                     "titulo": "Resoluci\u00f3n de 15 de diciembre de 2023, del Ayuntamiento de Manlleu (Barcelona), referente a la convocatoria para proveer varias plazas.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "190521",
#                                                                         "szKBytes": "186",
#                                                                         "pagina_inicial": "627",
#                                                                         "pagina_final": "627",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-157.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-157",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-157"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-158",
#                                                                     "control": "2023/26736",
#                                                                     "titulo": "Resoluci\u00f3n de 19 de diciembre de 2023, del Ayuntamiento de Alhama de Murcia (Murcia), referente a la convocatoria para proveer varias plazas.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "191847",
#                                                                         "szKBytes": "187",
#                                                                         "pagina_inicial": "628",
#                                                                         "pagina_final": "628",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-158.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-158",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-158"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-159",
#                                                                     "control": "2023/26930",
#                                                                     "titulo": "Resoluci\u00f3n de 19 de diciembre de 2023, del Ayuntamiento de Palencia, referente a la convocatoria para proveer varias plazas.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "191153",
#                                                                         "szKBytes": "187",
#                                                                         "pagina_inicial": "629",
#                                                                         "pagina_final": "629",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-159.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-159",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-159"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-160",
#                                                                     "control": "2023/26739",
#                                                                     "titulo": "Resoluci\u00f3n de 20 de diciembre de 2023, del Ayuntamiento de Arteixo (A Coru\u00f1a), referente a la convocatoria para proveer una plaza.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "192066",
#                                                                         "szKBytes": "188",
#                                                                         "pagina_inicial": "630",
#                                                                         "pagina_final": "630",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-160.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-160",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-160"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-161",
#                                                                     "control": "2023/26932",
#                                                                     "titulo": "Resoluci\u00f3n de 20 de diciembre de 2023, del Ayuntamiento de Quintanar de la Orden (Toledo), referente a la convocatoria para proveer una plaza.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "190890",
#                                                                         "szKBytes": "186",
#                                                                         "pagina_inicial": "631",
#                                                                         "pagina_final": "631",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-161.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-161",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-161"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-162",
#                                                                     "control": "2023/26933",
#                                                                     "titulo": "Resoluci\u00f3n de 20 de diciembre de 2023, del Ayuntamiento de Quintanar de la Orden (Toledo), referente a la convocatoria para proveer una plaza.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "190881",
#                                                                         "szKBytes": "186",
#                                                                         "pagina_inicial": "632",
#                                                                         "pagina_final": "632",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-162.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-162",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-162"
#                                                                 },
#                                                                 {
#                                                                     "identificador": "BOE-A-2024-163",
#                                                                     "control": "2023/26934",
#                                                                     "titulo": "Resoluci\u00f3n de 20 de diciembre de 2023, del Ayuntamiento de Torremolinos (M\u00e1laga), referente a la convocatoria para proveer varias plazas.",
#                                                                     "url_pdf": {
#                                                                         "szBytes": "195504",
#                                                                         "szKBytes": "191",
#                                                                         "pagina_inicial": "633",
#                                                                         "pagina_final": "634",
#                                                                         "texto": "https://www.boe.es/boe/dias/2024/01/03/pdfs/BOE-A-2024-163.pdf"
#                                                                     },
#                                                                     "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-A-2024-163",
#                                                                     "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-A-2024-163"
#                                                                 },
#                                                                 {
# ...
#                                                         {
#                                                             "identificador": "BOE-B-2024-247",
#                                                             "titulo": "Anuncio de la Direcci\u00f3n General de Industria, relativo a la necesidad de ocupaci\u00f3n de una superficie a expropiar de 30.000 m\u00b2 en la Concesi\u00f3n de explotaci\u00f3n minera de recursos de la Secci\u00f3n C) denominada \"Charco de San Francisco\", situada en el t\u00e9rmino municipal de G\u00e1ldar, isla de Gran Canaria, con Registro minero CDPI-149.",
#                                                             "url_pdf": {
#                                                                 "szBytes": "146090",
#                                                                 "szKBytes": "143",
#                                                                 "pagina_inicial": "530",
#                                                                 "pagina_final": "530",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-247.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-247",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-247"
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "310",
#                                                     "nombre": "UNIVERSIDADES",
#                                                     "item": [
#                                                         {
#                                                             "identificador": "BOE-B-2024-248",
#                                                             "titulo": "Anuncio de la Facultad de Econom\u00eda y Empresa de la Universidad del Pa\u00eds Vasco/Euskal Herriko Unibertsitatea sobre extrav\u00edo de t\u00edtulo universitario.",
#                                                             "url_pdf": {
#                                                                 "szBytes": "143452",
#                                                                 "szKBytes": "140",
#                                                                 "pagina_inicial": "531",
#                                                                 "pagina_final": "531",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-248.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-248",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-248"
#                                                         },
#                                                         {
#                                                             "identificador": "BOE-B-2024-249",
#                                                             "titulo": "Anuncio de la Facultad de Filosof\u00eda y Ciencias de la Educaci\u00f3n de la Universidad de Valencia sobre extrav\u00edo de t\u00edtulo universitario.",
#                                                             "url_pdf": {
#                                                                 "szBytes": "142693",
#                                                                 "szKBytes": "139",
#                                                                 "pagina_inicial": "532",
#                                                                 "pagina_final": "532",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-249.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-249",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-249"
#                                                         },
#                                                         {
#                                                             "identificador": "BOE-B-2024-250",
#                                                             "titulo": "Anuncio de Servicio de Pruebas de Acceso, T\u00edtulos y Becas de la Universidad Rey Juan Carlos sobre extrav\u00edo de t\u00edtulo universitario.",
#                                                             "url_pdf": {
#                                                                 "szBytes": "143284",
#                                                                 "szKBytes": "140",
#                                                                 "pagina_inicial": "533",
#                                                                 "pagina_final": "533",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-250.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-250",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-250"
#                                                         },
#                                                         {
#                                                             "identificador": "BOE-B-2024-251",
#                                                             "titulo": "Anuncio de la Facultad de Ciencias Sociales de la Universidad Antonio de Nebrija sobre extrav\u00edo de t\u00edtulo universitario.",
#                                                             "url_pdf": {
#                                                                 "szBytes": "143000",
#                                                                 "szKBytes": "140",
#                                                                 "pagina_inicial": "534",
#                                                                 "pagina_final": "534",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-251.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-251",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-251"
#                                                         }
#                                                     ]
#                                                 }
#                                             ]
#                                         },
#                                         {
#                                             "codigo": "5C",
#                                             "nombre": "V. Anuncios. - C. Anuncios particulares",
#                                             "departamento": [
#                                                 {
#                                                     "codigo": "9202",
#                                                     "nombre": "ANUNCIOS PARTICULARES",
#                                                     "item": [
#                                                         {
#                                                             "identificador": "BOE-B-2024-252",
#                                                             "titulo": "FUNDACI\u00d3N INSTITUTO CAMERAL PARA LA CREACI\u00d3N Y DESARROLLO DE LA EMPRESA (INCYDE).",
#                                                             "url_pdf": {
#                                                                 "szBytes": "149059",
#                                                                 "szKBytes": "146",
#                                                                 "pagina_inicial": "535",
#                                                                 "pagina_final": "536",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-252.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-252",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-252"
#                                                         },
#                                                         {
#                                                             "identificador": "BOE-B-2024-253",
#                                                             "titulo": "FUNDACI\u00d3N INSTITUTO CAMERAL PARA LA CREACI\u00d3N Y DESARROLLO DE LA EMPRESA (INCYDE).",
#                                                             "url_pdf": {
#                                                                 "szBytes": "149170",
#                                                                 "szKBytes": "146",
#                                                                 "pagina_inicial": "537",
#                                                                 "pagina_final": "538",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-253.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-253",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-253"
#                                                         }
#                                                     ]
#                                                 },
#                                                 {
#                                                     "codigo": "9583",
#                                                     "nombre": "CONVOCATORIAS DE JUNTAS",
#                                                     "item": [
#                                                         {
#                                                             "identificador": "BOE-B-2024-254",
#                                                             "titulo": "COMUNIDAD DE REGANTES ANDEVALO GUADIANA.",
#                                                             "url_pdf": {
#                                                                 "szBytes": "145105",
#                                                                 "szKBytes": "142",
#                                                                 "pagina_inicial": "539",
#                                                                 "pagina_final": "539",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-254.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-254",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-254"
#                                                         },
#                                                         {
#                                                             "identificador": "BOE-B-2024-255",
#                                                             "titulo": "COMUNIDAD DE REGANTES ANTIOQUIA",
#                                                             "url_pdf": {
#                                                                 "szBytes": "142801",
#                                                                 "szKBytes": "139",
#                                                                 "pagina_inicial": "540",
#                                                                 "pagina_final": "540",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-255.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-255",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-255"
#                                                         },
#                                                         {
#                                                             "identificador": "BOE-B-2024-256",
#                                                             "titulo": "COMUNIDAD DE USUARIOS DE SAN ESTEBAN DE BUDI\u00d1O.",
#                                                             "url_pdf": {
#                                                                 "szBytes": "143145",
#                                                                 "szKBytes": "140",
#                                                                 "pagina_inicial": "541",
#                                                                 "pagina_final": "541",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-256.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-256",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-256"
#                                                         },
#                                                         {
#                                                             "identificador": "BOE-B-2024-257",
#                                                             "titulo": "JUNTA CENTRAL DEL JALON.",
#                                                             "url_pdf": {
#                                                                 "szBytes": "143944",
#                                                                 "szKBytes": "141",
#                                                                 "pagina_inicial": "542",
#                                                                 "pagina_final": "542",
#                                                                 "texto": "https://www.boe.es/boe/dias/2024/01/04/pdfs/BOE-B-2024-257.pdf"
#                                                             },
#                                                             "url_html": "https://www.boe.es/diario_boe/txt.php?id=BOE-B-2024-257",
#                                                             "url_xml": "https://www.boe.es/diario_boe/xml.php?id=BOE-B-2024-257"
#                                                         }
#                                                     ]
#                                                 }
#                                             ]
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             }
#         }
#     }
# }
